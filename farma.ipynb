# %%
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler , OneHotEncoder
from feature_engine.outliers import Winsorizer
import joblib

# %%
datset = pd.read_csv(r"drug_regulatory_classification_dataset.csv")

# %%
datset.head()
# Out:
#    Dosage_mg  Price_Per_Unit  Production_Cost  Marketing_Spend  \
# 0        250          364.22           246.49        159132.53
# 1        500          112.86            73.22        260595.45
# 2        200          197.24           100.72        106818.45
# 3        500          373.55           264.76        231304.59
# 4        500          353.87           277.29        319403.02
#
#    Clinical_Trial_Phase  Side_Effect_Severity_Score  Abuse_Potential_Score  \
# 0                     3                        4.26                   2.52
# 1                     2                        8.12                   1.80
# 2                     3                        1.58                   1.47
# 3                     4                        1.72                   1.61
# 4                     2                        9.64                   0.45
#
#    Prescription_Rate  Hospital_Distribution_Percentage  \
# 0               0.74                             57.93
# 1               0.48                             48.00
# 2               0.93                             54.48
# 3               0.54                             47.20
# 4               0.50                             86.96
#
#    Pharmacy_Distribution_Percentage  ...  Manufacturing_Region  \
# 0                             42.07  ...                 South
# 1                             52.00  ...                  East
# 2                             45.52  ...                 North
# 3                             52.80  ...                 North
# 4                             13.04  ...                 North
#
#    Requires_Cold_Storage  OTC_Flag  High_Risk_Substance  \
# 0                     No        No                   No
# 1                    Yes       Yes                   No
# 2                    Yes       Yes                   No
# 3                     No       Yes                   No
# 4                     No       Yes                   No
#
#    Insurance_Coverage_Percentage  Export_Percentage  Online_Sales_Percentage  \
# 0                          64.46              41.88                    41.15
# 1                          93.37              10.30                    50.05
# 2                          64.53              34.21                    46.42
# 3                          95.21              71.04                    49.52
# 4                          98.05              70.28                    44.90
#
#    Brand_Reputation_Score Doctor_Recommendation_Rate Target_Regulatory_Class
# 0                    6.56                       0.47      Non-Regulated Drug
# 1                    4.01                       0.44      Non-Regulated Drug
# 2                    5.95                       0.16      Non-Regulated Drug
# 3                    9.65                       0.76      Non-Regulated Drug
# 4                    1.79                       0.36      Non-Regulated Drug
#
# [5 rows x 30 columns]

# %%
datset.tail()
# Out:
#        Dosage_mg  Price_Per_Unit  Production_Cost  Marketing_Spend  \
# 59995        200          260.68           167.61        337160.40
# 59996        200          249.67           139.19        457366.23
# 59997        100          155.15            78.35        367705.08
# 59998        500           42.46            19.05        259954.00
# 59999        250          153.99            83.04        267876.28
#
#        Clinical_Trial_Phase  Side_Effect_Severity_Score  \
# 59995                     2                        6.04
# 59996                     2                        8.51
# 59997                     4                        6.45
# 59998                     1                        6.98
# 59999                     1                        1.51
#
#        Abuse_Potential_Score  Prescription_Rate  \
# 59995                   2.79               0.92
# 59996                   1.94               0.86
# 59997                   2.36               0.85
# 59998                   2.29               0.16
# 59999                   1.15               0.51
#
#        Hospital_Distribution_Percentage  Pharmacy_Distribution_Percentage  \
# 59995                             67.01                             32.99
# 59996                             50.66                             49.34
# 59997                             26.03                             73.97
# 59998                             39.96                             60.04
# 59999                             52.75                             47.25
#
#        ...  Manufacturing_Region  Requires_Cold_Storage  OTC_Flag  \
# 59995  ...                  East                    Yes        No
# 59996  ...                 South                    Yes        No
# 59997  ...                 South                    Yes       Yes
# 59998  ...                 North                     No       Yes
# 59999  ...                 North                    Yes       Yes
#
#        High_Risk_Substance  Insurance_Coverage_Percentage  Export_Percentage  \
# 59995                   No                          60.31              73.67
# 59996                   No                          31.87              38.08
# 59997                   No                          35.96              19.06
# 59998                   No                          67.17              57.80
# 59999                   No                          82.20              10.26
#
#        Online_Sales_Percentage  Brand_Reputation_Score  \
# 59995                    25.44                    2.97
# 59996                    56.10                    6.75
# 59997                    25.10                    9.75
# 59998                    28.23                    3.00
# 59999                    22.85                    5.38
#
#       Doctor_Recommendation_Rate Target_Regulatory_Class
# 59995                       0.95          Regulated Drug
# 59996                       0.91          Regulated Drug
# 59997                       0.60      Non-Regulated Drug
# 59998                       0.39          Regulated Drug
# 59999                       0.87      Non-Regulated Drug
#
# [5 rows x 30 columns]

# %%
datset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Dosage_mg                         60000 non-null  int64
#  1   Price_Per_Unit                    60000 non-null  float64
#  2   Production_Cost                   60000 non-null  float64
#  3   Marketing_Spend                   60000 non-null  float64
#  4   Clinical_Trial_Phase              60000 non-null  int64
#  5   Side_Effect_Severity_Score        60000 non-null  float64
#  6   Abuse_Potential_Score             60000 non-null  float64
#  7   Prescription_Rate                 60000 non-null  float64
#  8   Hospital_Distribution_Percentage  60000 non-null  float64
#  9   Pharmacy_Distribution_Percentage  60000 non-null  float64
#  10  Annual_Sales_Volume               60000 non-null  float64
#  11  Regulatory_Risk_Score             60000 non-null  float64
#  12  Approval_Time_Months              60000 non-null  int64
#  13  Patent_Duration_Years             60000 non-null  int64
#  14  R&D_Investment_Million            60000 non-null  float64
#  15  Competitor_Count                  60000 non-null  int64
#  16  Recall_History_Count              60000 non-null  int64
#  17  Adverse_Event_Reports             60000 non-null  int64
#  18  Drug_Form                         60000 non-null  object
#  19  Therapeutic_Class                 60000 non-null  object
#  20  Manufacturing_Region              60000 non-null  object
#  21  Requires_Cold_Storage             60000 non-null  object
#  22  OTC_Flag                          60000 non-null  object
#  23  High_Risk_Substance               60000 non-null  object
#  24  Insurance_Coverage_Percentage     60000 non-null  float64
#  25  Export_Percentage                 60000 non-null  float64
#  26  Online_Sales_Percentage           60000 non-null  float64
#  27  Brand_Reputation_Score            60000 non-null  float64
#  28  Doctor_Recommendation_Rate        60000 non-null  float64
#  29  Target_Regulatory_Class           57000 non-null  object
# dtypes: float64(16), int64(7), object(7)
# memory usage: 13.7+ MB

# %%
#seprate features and target.
x=datset.iloc[:,1:]
y=datset.iloc[:,0]

# %%
numeric_features = x.select_dtypes(exclude=['object']).columns
categorical_features = x.select_dtypes(include=['object']).columns

# %%
# Numerical Pipeline
num_pipeline = Pipeline([
    ("impute", SimpleImputer(strategy='mean')),
    ("winsorizer", Winsorizer(capping_method='iqr', tail='both', fold=1.5)),
    ("scale", MinMaxScaler())
])

# Categorical Pipeline
categ_pipeline = Pipeline([
    ("impute", SimpleImputer(strategy='most_frequent')),
    ("encode", OneHotEncoder(drop='first'))
])

# %%
from sklearn.compose import ColumnTransformer

preprocess_pipeline = ColumnTransformer([
    ('numerical', num_pipeline, numeric_features),
    ('categorical', categ_pipeline, categorical_features)
])
